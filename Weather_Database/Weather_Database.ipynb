# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 776

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | pringsewu
# Processing Record 2 of Set 1 | broken hill
# Processing Record 3 of Set 1 | hilo
# Processing Record 4 of Set 1 | tuktoyaktuk
# Processing Record 5 of Set 1 | esperance
# Processing Record 6 of Set 1 | kaitangata
# Processing Record 7 of Set 1 | baykalsk
# Processing Record 8 of Set 1 | svetlogorsk
# Processing Record 9 of Set 1 | san pedro
# Processing Record 10 of Set 1 | torbay
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | tete
# Processing Record 13 of Set 1 | chicama
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | lagunas
# Processing Record 16 of Set 1 | ahuimanu
# Processing Record 17 of Set 1 | alofi
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | ndele
# Processing Record 20 of Set 1 | atuona
# Processing Record 21 of Set 1 | dikson
# Processing Record 22 of Set 1 | hermanus
# Processing Record 23 of Set 1 | porto novo
# Processing Record 24 of Set 1 | cape town
# Processing Record 25 of Set 1 | praya
# Processing Record 26 of Set 1 | punta arenas
# Processing Record 27 of Set 1 | yertsevo
# Processing Record 28 of Set 1 | georgetown
# Processing Record 29 of Set 1 | fairbanks
# Processing Record 30 of Set 1 | cherskiy
# Processing Record 31 of Set 1 | yellowknife
# Processing Record 32 of Set 1 | salalah
# Processing Record 33 of Set 1 | kapaa
# Processing Record 34 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 35 of Set 1 | sitka
# Processing Record 36 of Set 1 | hazorasp
# Processing Record 37 of Set 1 | sao filipe
# Processing Record 38 of Set 1 | vila franca do campo
# Processing Record 39 of Set 1 | linguere
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 42 of Set 1 | castro
# Processing Record 43 of Set 1 | rikitea
# Processing Record 44 of Set 1 | hobart
# Processing Record 45 of Set 1 | haines junction
# Processing Record 46 of Set 1 | gangotri
# City not found. Skipping...
# Processing Record 47 of Set 1 | qaanaaq
# Processing Record 48 of Set 1 | lagoa
# Processing Record 49 of Set 1 | carbonia
# Processing Record 50 of Set 1 | san patricio
# Processing Record 1 of Set 2 | saint-philippe
# Processing Record 2 of Set 2 | husavik
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | sur
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | kangaba
# Processing Record 8 of Set 2 | chokurdakh
# Processing Record 9 of Set 2 | katsuura
# Processing Record 10 of Set 2 | half moon bay
# Processing Record 11 of Set 2 | ushuaia
# Processing Record 12 of Set 2 | mahebourg
# Processing Record 13 of Set 2 | cabo san lucas
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | flin flon
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | saint combs
# City not found. Skipping...
# Processing Record 19 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 20 of Set 2 | szczecinek
# Processing Record 21 of Set 2 | fortuna
# Processing Record 22 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 23 of Set 2 | baherden
# Processing Record 24 of Set 2 | asau
# Processing Record 25 of Set 2 | thompson
# Processing Record 26 of Set 2 | tacuarembo
# Processing Record 27 of Set 2 | el faiyum
# City not found. Skipping...
# Processing Record 28 of Set 2 | sampit
# Processing Record 29 of Set 2 | shush
# Processing Record 30 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 31 of Set 2 | flinders
# Processing Record 32 of Set 2 | sembakung
# Processing Record 33 of Set 2 | pestovo
# Processing Record 34 of Set 2 | jiayuguan
# Processing Record 35 of Set 2 | lithakia
# Processing Record 36 of Set 2 | tasiilaq
# Processing Record 37 of Set 2 | itupiranga
# Processing Record 38 of Set 2 | bireun
# Processing Record 39 of Set 2 | nizhniy tsasuchey
# Processing Record 40 of Set 2 | east london
# Processing Record 41 of Set 2 | eyemouth
# Processing Record 42 of Set 2 | kruisfontein
# Processing Record 43 of Set 2 | sorland
# Processing Record 44 of Set 2 | bull savanna
# Processing Record 45 of Set 2 | port lincoln
# Processing Record 46 of Set 2 | vershino-darasunskiy
# Processing Record 47 of Set 2 | male
# Processing Record 48 of Set 2 | bengkulu
# Processing Record 49 of Set 2 | mogadishu
# Processing Record 50 of Set 2 | port blair
# Processing Record 1 of Set 3 | ahipara
# Processing Record 2 of Set 3 | hasaki
# Processing Record 3 of Set 3 | leningradskiy
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | arraial do cabo
# Processing Record 6 of Set 3 | sarai
# Processing Record 7 of Set 3 | iqaluit
# Processing Record 8 of Set 3 | iisalmi
# Processing Record 9 of Set 3 | drumheller
# Processing Record 10 of Set 3 | ponta do sol
# Processing Record 11 of Set 3 | dongning
# Processing Record 12 of Set 3 | evensk
# Processing Record 13 of Set 3 | taguatinga
# Processing Record 14 of Set 3 | severo-kurilsk
# Processing Record 15 of Set 3 | vlcnov
# Processing Record 16 of Set 3 | cayenne
# Processing Record 17 of Set 3 | bluff
# Processing Record 18 of Set 3 | port perry
# Processing Record 19 of Set 3 | taksimo
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | saskylakh
# Processing Record 22 of Set 3 | akyab
# Processing Record 23 of Set 3 | puerto baquerizo moreno
# Processing Record 24 of Set 3 | nikolskoye
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | klaksvik
# Processing Record 27 of Set 3 | victoria
# Processing Record 28 of Set 3 | zharkovskiy
# Processing Record 29 of Set 3 | kibala
# Processing Record 30 of Set 3 | oussouye
# Processing Record 31 of Set 3 | arenapolis
# Processing Record 32 of Set 3 | hoghiz
# Processing Record 33 of Set 3 | high rock
# Processing Record 34 of Set 3 | marienburg
# Processing Record 35 of Set 3 | buluang
# Processing Record 36 of Set 3 | velingrad
# Processing Record 37 of Set 3 | bilibino
# Processing Record 38 of Set 3 | kilindoni
# Processing Record 39 of Set 3 | coria
# Processing Record 40 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 41 of Set 3 | shingu
# Processing Record 42 of Set 3 | nelson bay
# Processing Record 43 of Set 3 | amos
# Processing Record 44 of Set 3 | luorong
# Processing Record 45 of Set 3 | bontang
# Processing Record 46 of Set 3 | zhigansk
# Processing Record 47 of Set 3 | noumea
# Processing Record 48 of Set 3 | portland
# Processing Record 49 of Set 3 | ambon
# Processing Record 50 of Set 3 | teya
# Processing Record 1 of Set 4 | longyearbyen
# Processing Record 2 of Set 4 | pavlodolskaya
# Processing Record 3 of Set 4 | mbuji-mayi
# Processing Record 4 of Set 4 | hagdan
# Processing Record 5 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 6 of Set 4 | inhambane
# Processing Record 7 of Set 4 | bredasdorp
# Processing Record 8 of Set 4 | okandja
# City not found. Skipping...
# Processing Record 9 of Set 4 | namibe
# Processing Record 10 of Set 4 | aklavik
# Processing Record 11 of Set 4 | kachiry
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | guerrero negro
# Processing Record 16 of Set 4 | avarua
# Processing Record 17 of Set 4 | alice springs
# Processing Record 18 of Set 4 | tiksi
# Processing Record 19 of Set 4 | arlit
# Processing Record 20 of Set 4 | coahuayana
# Processing Record 21 of Set 4 | uyemskiy
# Processing Record 22 of Set 4 | marshfield
# Processing Record 23 of Set 4 | nouadhibou
# Processing Record 24 of Set 4 | maldonado
# Processing Record 25 of Set 4 | labuhan
# Processing Record 26 of Set 4 | tukrah
# Processing Record 27 of Set 4 | port-cartier
# Processing Record 28 of Set 4 | tabou
# Processing Record 29 of Set 4 | tatawin
# Processing Record 30 of Set 4 | airai
# Processing Record 31 of Set 4 | ponta delgada
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | sangueya
# Processing Record 34 of Set 4 | grigoropolisskaya
# Processing Record 35 of Set 4 | aginskoye
# Processing Record 36 of Set 4 | puerto ayora
# Processing Record 37 of Set 4 | shu
# Processing Record 38 of Set 4 | furano
# Processing Record 39 of Set 4 | winneba
# Processing Record 40 of Set 4 | nome
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | newport
# Processing Record 43 of Set 4 | clyde river
# Processing Record 44 of Set 4 | teguldet
# Processing Record 45 of Set 4 | lata
# Processing Record 46 of Set 4 | faanui
# Processing Record 47 of Set 4 | lebu
# Processing Record 48 of Set 4 | luderitz
# Processing Record 49 of Set 4 | tono
# Processing Record 50 of Set 4 | kismayo
# Processing Record 1 of Set 5 | comarapa
# Processing Record 2 of Set 5 | bethel
# Processing Record 3 of Set 5 | blagoveshchenka
# Processing Record 4 of Set 5 | new norfolk
# Processing Record 5 of Set 5 | ous
# Processing Record 6 of Set 5 | barcelos
# Processing Record 7 of Set 5 | san cristobal
# Processing Record 8 of Set 5 | gat
# Processing Record 9 of Set 5 | vaitape
# Processing Record 10 of Set 5 | kenora
# Processing Record 11 of Set 5 | zilair
# Processing Record 12 of Set 5 | pacific grove
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | auki
# Processing Record 15 of Set 5 | iquique
# Processing Record 16 of Set 5 | port hedland
# Processing Record 17 of Set 5 | senanga
# Processing Record 18 of Set 5 | saint george
# Processing Record 19 of Set 5 | byron bay
# Processing Record 20 of Set 5 | petukhovo
# Processing Record 21 of Set 5 | gravdal
# Processing Record 22 of Set 5 | hami
# Processing Record 23 of Set 5 | portobelo
# Processing Record 24 of Set 5 | ulladulla
# Processing Record 25 of Set 5 | vilsbiburg
# Processing Record 26 of Set 5 | mandalgovi
# Processing Record 27 of Set 5 | micheweni
# Processing Record 28 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 5 | jalu
# Processing Record 30 of Set 5 | monte alegre
# Processing Record 31 of Set 5 | severo-yeniseyskiy
# Processing Record 32 of Set 5 | matagami
# Processing Record 33 of Set 5 | kavaratti
# Processing Record 34 of Set 5 | artyom
# Processing Record 35 of Set 5 | magadan
# Processing Record 36 of Set 5 | saldanha
# Processing Record 37 of Set 5 | concarneau
# Processing Record 38 of Set 5 | makakilo city
# Processing Record 39 of Set 5 | tobermory
# Processing Record 40 of Set 5 | gallup
# Processing Record 41 of Set 5 | karamay
# City not found. Skipping...
# Processing Record 42 of Set 5 | buritis
# Processing Record 43 of Set 5 | tocopilla
# Processing Record 44 of Set 5 | beohari
# Processing Record 45 of Set 5 | murdochville
# Processing Record 46 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 47 of Set 5 | chhukha
# City not found. Skipping...
# Processing Record 48 of Set 5 | sao joao da barra
# Processing Record 49 of Set 5 | suihua
# Processing Record 50 of Set 5 | plettenberg bay
# Processing Record 1 of Set 6 | souillac
# Processing Record 2 of Set 6 | kousseri
# Processing Record 3 of Set 6 | lugo
# Processing Record 4 of Set 6 | sokur
# Processing Record 5 of Set 6 | barrow
# Processing Record 6 of Set 6 | candawaga
# City not found. Skipping...
# Processing Record 7 of Set 6 | dryden
# Processing Record 8 of Set 6 | ambanja
# Processing Record 9 of Set 6 | samarai
# Processing Record 10 of Set 6 | sobolevo
# Processing Record 11 of Set 6 | carnarvon
# Processing Record 12 of Set 6 | coquimbo
# Processing Record 13 of Set 6 | mocoa
# Processing Record 14 of Set 6 | narsaq
# Processing Record 15 of Set 6 | cotonou
# Processing Record 16 of Set 6 | zhezkazgan
# Processing Record 17 of Set 6 | north bend
# Processing Record 18 of Set 6 | bayir
# Processing Record 19 of Set 6 | sakakah
# Processing Record 20 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 6 | seddon
# Processing Record 22 of Set 6 | sokol
# Processing Record 23 of Set 6 | keti bandar
# Processing Record 24 of Set 6 | ville-marie
# Processing Record 25 of Set 6 | lasa
# Processing Record 26 of Set 6 | klyuchi
# Processing Record 27 of Set 6 | alakurtti
# Processing Record 28 of Set 6 | northam
# Processing Record 29 of Set 6 | waipawa
# Processing Record 30 of Set 6 | pergamino
# Processing Record 31 of Set 6 | minsk
# Processing Record 32 of Set 6 | arona
# Processing Record 33 of Set 6 | port moresby
# Processing Record 34 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 35 of Set 6 | talnakh
# Processing Record 36 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 6 | mount gambier
# Processing Record 38 of Set 6 | ankola
# Processing Record 39 of Set 6 | sabang
# Processing Record 40 of Set 6 | naushki
# Processing Record 41 of Set 6 | dawson creek
# Processing Record 42 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 43 of Set 6 | chagda
# City not found. Skipping...
# Processing Record 44 of Set 6 | bonnyville
# Processing Record 45 of Set 6 | udachnyy
# Processing Record 46 of Set 6 | krasnoselkup
# Processing Record 47 of Set 6 | lompoc
# Processing Record 48 of Set 6 | nisia floresta
# Processing Record 49 of Set 6 | sandpoint
# Processing Record 50 of Set 6 | tuatapere
# Processing Record 1 of Set 7 | viedma
# Processing Record 2 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 3 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 4 of Set 7 | misratah
# Processing Record 5 of Set 7 | rawson
# Processing Record 6 of Set 7 | coxim
# Processing Record 7 of Set 7 | lodja
# Processing Record 8 of Set 7 | caraballeda
# Processing Record 9 of Set 7 | horta
# Processing Record 10 of Set 7 | kahului
# Processing Record 11 of Set 7 | eydhafushi
# Processing Record 12 of Set 7 | padang
# Processing Record 13 of Set 7 | homer
# Processing Record 14 of Set 7 | wladyslawowo
# Processing Record 15 of Set 7 | otjimbingwe
# Processing Record 16 of Set 7 | saint-augustin
# Processing Record 17 of Set 7 | khatanga
# Processing Record 18 of Set 7 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 7 | siljan
# Processing Record 20 of Set 7 | hithadhoo
# Processing Record 21 of Set 7 | geraldton
# Processing Record 22 of Set 7 | roald
# Processing Record 23 of Set 7 | upernavik
# Processing Record 24 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 25 of Set 7 | maisuru
# City not found. Skipping...
# Processing Record 26 of Set 7 | suraabad
# Processing Record 27 of Set 7 | grand-bourg
# Processing Record 28 of Set 7 | valparaiso
# Processing Record 29 of Set 7 | rio gallegos
# Processing Record 30 of Set 7 | yerbogachen
# Processing Record 31 of Set 7 | santa cruz
# Processing Record 32 of Set 7 | belmonte
# Processing Record 33 of Set 7 | kandrian
# Processing Record 34 of Set 7 | scunthorpe
# Processing Record 35 of Set 7 | bathsheba
# Processing Record 36 of Set 7 | puerto suarez
# Processing Record 37 of Set 7 | preeceville
# Processing Record 38 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 7 | abaete
# Processing Record 40 of Set 7 | henties bay
# Processing Record 41 of Set 7 | broome
# Processing Record 42 of Set 7 | meulaboh
# Processing Record 43 of Set 7 | cap malheureux
# Processing Record 44 of Set 7 | jasper
# Processing Record 45 of Set 7 | grafton
# Processing Record 46 of Set 7 | pitimbu
# Processing Record 47 of Set 7 | hamilton
# Processing Record 48 of Set 7 | kloulklubed
# Processing Record 49 of Set 7 | kavieng
# Processing Record 50 of Set 7 | keetmanshoop
# Processing Record 1 of Set 8 | charleston
# Processing Record 2 of Set 8 | grindavik
# Processing Record 3 of Set 8 | tautira
# Processing Record 4 of Set 8 | margate
# Processing Record 5 of Set 8 | khuzhir
# Processing Record 6 of Set 8 | marawi
# Processing Record 7 of Set 8 | yingkou
# Processing Record 8 of Set 8 | kungurtug
# Processing Record 9 of Set 8 | buchanan
# Processing Record 10 of Set 8 | rosa zarate
# Processing Record 11 of Set 8 | caramay
# Processing Record 12 of Set 8 | vao
# Processing Record 13 of Set 8 | savigliano
# Processing Record 14 of Set 8 | dunedin
# Processing Record 15 of Set 8 | viransehir
# Processing Record 16 of Set 8 | pangnirtung
# Processing Record 17 of Set 8 | moba
# Processing Record 18 of Set 8 | riachao do jacuipe
# Processing Record 19 of Set 8 | eirunepe
# Processing Record 20 of Set 8 | tual
# Processing Record 21 of Set 8 | itarema
# Processing Record 22 of Set 8 | beringovskiy
# Processing Record 23 of Set 8 | bandarbeyla
# Processing Record 24 of Set 8 | nabire
# Processing Record 25 of Set 8 | catemaco
# Processing Record 26 of Set 8 | dingle
# Processing Record 27 of Set 8 | trincomalee
# Processing Record 28 of Set 8 | sukhumi
# Processing Record 29 of Set 8 | coihaique
# Processing Record 30 of Set 8 | san martin
# Processing Record 31 of Set 8 | paita
# Processing Record 32 of Set 8 | banyliv
# Processing Record 33 of Set 8 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 8 | mahibadhoo
# Processing Record 35 of Set 8 | mehamn
# Processing Record 36 of Set 8 | moose factory
# Processing Record 37 of Set 8 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 8 | norman wells
# Processing Record 39 of Set 8 | soto la marina
# Processing Record 40 of Set 8 | camacha
# Processing Record 41 of Set 8 | ribas do rio pardo
# Processing Record 42 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 43 of Set 8 | bambous virieux
# Processing Record 44 of Set 8 | winnemucca
# Processing Record 45 of Set 8 | sao paulo de olivenca
# Processing Record 46 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 47 of Set 8 | olyka
# Processing Record 48 of Set 8 | laguna
# Processing Record 49 of Set 8 | altamira
# Processing Record 50 of Set 8 | hambantota
# Processing Record 1 of Set 9 | baykit
# Processing Record 2 of Set 9 | mbulu
# Processing Record 3 of Set 9 | qena
# Processing Record 4 of Set 9 | burica
# City not found. Skipping...
# Processing Record 5 of Set 9 | chipiona
# Processing Record 6 of Set 9 | muros
# Processing Record 7 of Set 9 | tandil
# Processing Record 8 of Set 9 | korla
# Processing Record 9 of Set 9 | jiangyou
# Processing Record 10 of Set 9 | kuching
# Processing Record 11 of Set 9 | maarianhamina
# Processing Record 12 of Set 9 | zhuanghe
# Processing Record 13 of Set 9 | lamesa
# Processing Record 14 of Set 9 | berlevag
# Processing Record 15 of Set 9 | nemuro
# Processing Record 16 of Set 9 | ancud
# Processing Record 17 of Set 9 | san quintin
# Processing Record 18 of Set 9 | usakos
# Processing Record 19 of Set 9 | bahia blanca
# Processing Record 20 of Set 9 | monte patria
# Processing Record 21 of Set 9 | port elizabeth
# Processing Record 22 of Set 9 | shelburne
# Processing Record 23 of Set 9 | ballina
# Processing Record 24 of Set 9 | youghal
# Processing Record 25 of Set 9 | cidreira
# Processing Record 26 of Set 9 | fort nelson
# Processing Record 27 of Set 9 | irbil
# Processing Record 28 of Set 9 | rehoboth
# Processing Record 29 of Set 9 | pisco
# Processing Record 30 of Set 9 | grand gaube
# Processing Record 31 of Set 9 | shancheng
# Processing Record 32 of Set 9 | mahadday weyne
# City not found. Skipping...
# Processing Record 33 of Set 9 | ratnagiri
# Processing Record 34 of Set 9 | manacor
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | saint-joseph
# Processing Record 37 of Set 9 | egvekinot
# Processing Record 38 of Set 9 | hulan
# Processing Record 39 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 40 of Set 9 | ostrovnoy
# Processing Record 41 of Set 9 | prince george
# Processing Record 42 of Set 9 | aranos
# Processing Record 43 of Set 9 | te anau
# Processing Record 44 of Set 9 | bom jesus da lapa
# Processing Record 45 of Set 9 | cermik
# Processing Record 46 of Set 9 | beloha
# Processing Record 47 of Set 9 | la rioja
# Processing Record 48 of Set 9 | iralaya
# Processing Record 49 of Set 9 | teberda
# Processing Record 50 of Set 9 | nipawin
# Processing Record 1 of Set 10 | staryy nadym
# Processing Record 2 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 3 of Set 10 | voyvozh
# Processing Record 4 of Set 10 | zinder
# Processing Record 5 of Set 10 | bulgan
# Processing Record 6 of Set 10 | pangody
# Processing Record 7 of Set 10 | tanda
# Processing Record 8 of Set 10 | fiumicino
# Processing Record 9 of Set 10 | gloucester
# Processing Record 10 of Set 10 | xiaoweizhai
# Processing Record 11 of Set 10 | dzaoudzi
# Processing Record 12 of Set 10 | touros
# Processing Record 13 of Set 10 | methoni
# Processing Record 14 of Set 10 | tilichiki
# Processing Record 15 of Set 10 | carutapera
# Processing Record 16 of Set 10 | ilo
# Processing Record 17 of Set 10 | lewistown
# Processing Record 18 of Set 10 | nynashamn
# Processing Record 19 of Set 10 | erenhot
# Processing Record 20 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 10 | santa cruz de la palma
# Processing Record 22 of Set 10 | brae
# Processing Record 23 of Set 10 | pangkalanbuun
# Processing Record 24 of Set 10 | yulara
# Processing Record 25 of Set 10 | maltahohe
# Processing Record 26 of Set 10 | zhanaozen
# Processing Record 27 of Set 10 | nongstoin
# Processing Record 28 of Set 10 | aporawan
# City not found. Skipping...
# Processing Record 29 of Set 10 | kudahuvadhoo
# Processing Record 30 of Set 10 | jaltepec
# Processing Record 31 of Set 10 | ngunguru
# Processing Record 32 of Set 10 | noyabrsk
# Processing Record 33 of Set 10 | teneguiban
# City not found. Skipping...
# Processing Record 34 of Set 10 | manta
# Processing Record 35 of Set 10 | pevek
# Processing Record 36 of Set 10 | kampong cham
# Processing Record 37 of Set 10 | osmena
# Processing Record 38 of Set 10 | atambua
# Processing Record 39 of Set 10 | okhotsk
# Processing Record 40 of Set 10 | mayumba
# Processing Record 41 of Set 10 | uruana
# Processing Record 42 of Set 10 | sechura
# Processing Record 43 of Set 10 | aden
# Processing Record 44 of Set 10 | balarampur
# Processing Record 45 of Set 10 | madang
# Processing Record 46 of Set 10 | willowmore
# Processing Record 47 of Set 10 | bogalusa
# Processing Record 48 of Set 10 | karratha
# Processing Record 49 of Set 10 | merauke
# Processing Record 50 of Set 10 | algiers
# Processing Record 1 of Set 11 | yeppoon
# Processing Record 2 of Set 11 | kochevo
# Processing Record 3 of Set 11 | stoyba
# City not found. Skipping...
# Processing Record 4 of Set 11 | ocampo
# Processing Record 5 of Set 11 | olafsvik
# Processing Record 6 of Set 11 | baruun-urt
# Processing Record 7 of Set 11 | syamzha
# Processing Record 8 of Set 11 | duncan
# Processing Record 9 of Set 11 | kaupanger
# Processing Record 10 of Set 11 | fernley
# Processing Record 11 of Set 11 | nalut
# Processing Record 12 of Set 11 | sayyan
# Processing Record 13 of Set 11 | ardmore
# Processing Record 14 of Set 11 | tiznit
# Processing Record 15 of Set 11 | griffith
# Processing Record 16 of Set 11 | kutum
# Processing Record 17 of Set 11 | knysna
# Processing Record 18 of Set 11 | praia da vitoria
# Processing Record 19 of Set 11 | halifax
# Processing Record 20 of Set 11 | topeka
# Processing Record 21 of Set 11 | tynda
# Processing Record 22 of Set 11 | sinnamary
# Processing Record 23 of Set 11 | yabelo
# Processing Record 24 of Set 11 | kasempa
# Processing Record 25 of Set 11 | jiexiu
# Processing Record 26 of Set 11 | russell
# Processing Record 27 of Set 11 | charters towers
# Processing Record 28 of Set 11 | inta
# Processing Record 29 of Set 11 | bollnas
# Processing Record 30 of Set 11 | guararapes
# Processing Record 31 of Set 11 | otatitlan
# Processing Record 32 of Set 11 | noshiro
# Processing Record 33 of Set 11 | san ignacio
# Processing Record 34 of Set 11 | katy
# Processing Record 35 of Set 11 | san vicente
# Processing Record 36 of Set 11 | ak-dovurak
# Processing Record 37 of Set 11 | olga
# Processing Record 38 of Set 11 | kalmunai
# Processing Record 39 of Set 11 | codrington
# Processing Record 40 of Set 11 | kirakira
# Processing Record 41 of Set 11 | ayr
# Processing Record 42 of Set 11 | vallentuna
# Processing Record 43 of Set 11 | ust-nera
# Processing Record 44 of Set 11 | tamiahua
# Processing Record 45 of Set 11 | huarmey
# Processing Record 46 of Set 11 | baiyin
# Processing Record 47 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 48 of Set 11 | vangaindrano
# Processing Record 49 of Set 11 | atbasar
# Processing Record 50 of Set 11 | alta floresta
# Processing Record 1 of Set 12 | saint-denis
# Processing Record 2 of Set 12 | tiruvottiyur
# City not found. Skipping...
# Processing Record 3 of Set 12 | jaguarao
# Processing Record 4 of Set 12 | ambodifototra
# City not found. Skipping...
# Processing Record 5 of Set 12 | harlingen
# Processing Record 6 of Set 12 | smithers
# Processing Record 7 of Set 12 | stanilesti
# Processing Record 8 of Set 12 | khao wong
# Processing Record 9 of Set 12 | biltine
# Processing Record 10 of Set 12 | poum
# Processing Record 11 of Set 12 | launceston
# Processing Record 12 of Set 12 | jaguey grande
# Processing Record 13 of Set 12 | waltershausen
# Processing Record 14 of Set 12 | dongsheng
# Processing Record 15 of Set 12 | marang
# Processing Record 16 of Set 12 | tura
# Processing Record 17 of Set 12 | selma
# Processing Record 18 of Set 12 | sioux lookout
# Processing Record 19 of Set 12 | nha trang
# Processing Record 20 of Set 12 | nara
# Processing Record 21 of Set 12 | thunder bay
# Processing Record 22 of Set 12 | sola
# Processing Record 23 of Set 12 | ilulissat
# Processing Record 24 of Set 12 | la ronge
# Processing Record 25 of Set 12 | molchanovo
# Processing Record 26 of Set 12 | bodden town
# Processing Record 27 of Set 12 | talcahuano
# Processing Record 28 of Set 12 | obukhiv
# Processing Record 29 of Set 12 | inongo
# Processing Record 30 of Set 12 | najran
# Processing Record 31 of Set 12 | ranchi
# Processing Record 32 of Set 12 | ust-kuyga
# Processing Record 33 of Set 12 | ko samui
# Processing Record 34 of Set 12 | chuguyevka
# Processing Record 35 of Set 12 | fairlie
# Processing Record 36 of Set 12 | kieta
# Processing Record 37 of Set 12 | majene
# Processing Record 38 of Set 12 | alnavar
# Processing Record 39 of Set 12 | uniontown
# Processing Record 40 of Set 12 | benguela
# Processing Record 41 of Set 12 | srednekolymsk
# Processing Record 42 of Set 12 | aguie
# Processing Record 43 of Set 12 | buenos aires
# Processing Record 44 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 45 of Set 12 | daru
# Processing Record 46 of Set 12 | nanzhou
# Processing Record 47 of Set 12 | mattru
# Processing Record 48 of Set 12 | nanyang
# Processing Record 49 of Set 12 | moindou
# Processing Record 50 of Set 12 | vuktyl
# Processing Record 1 of Set 13 | poronaysk
# Processing Record 2 of Set 13 | hondo
# Processing Record 3 of Set 13 | batagay-alyta
# Processing Record 4 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 13 | havoysund
# Processing Record 6 of Set 13 | vylok
# Processing Record 7 of Set 13 | san jose
# Processing Record 8 of Set 13 | pacasmayo
# Processing Record 9 of Set 13 | lorengau
# Processing Record 10 of Set 13 | laramie
# Processing Record 11 of Set 13 | banjarmasin
# Processing Record 12 of Set 13 | harper
# Processing Record 13 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 14 of Set 13 | walvis bay
# Processing Record 15 of Set 13 | coulihaut
# City not found. Skipping...
# Processing Record 16 of Set 13 | solnechnyy
# Processing Record 17 of Set 13 | perbaungan
# Processing Record 18 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 19 of Set 13 | rabo de peixe
# Processing Record 20 of Set 13 | dubai
# Processing Record 21 of Set 13 | aripuana
# Processing Record 22 of Set 13 | grand river south east
# City not found. Skipping...
# Processing Record 23 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 24 of Set 13 | belaya gora
# Processing Record 25 of Set 13 | jawhar
# Processing Record 26 of Set 13 | hovd
# Processing Record 27 of Set 13 | skjervoy
# Processing Record 28 of Set 13 | nuuk
# Processing Record 29 of Set 13 | imuris
# Processing Record 30 of Set 13 | goderich
# Processing Record 31 of Set 13 | riyadh
# Processing Record 32 of Set 13 | sambava
# Processing Record 33 of Set 13 | amahai
# Processing Record 34 of Set 13 | crestline
# Processing Record 35 of Set 13 | nantucket
# Processing Record 36 of Set 13 | champerico
# Processing Record 37 of Set 13 | gannan
# Processing Record 38 of Set 13 | high level
# Processing Record 39 of Set 13 | taoudenni
# Processing Record 40 of Set 13 | gushi
# Processing Record 41 of Set 13 | nazca
# Processing Record 42 of Set 13 | constantine
# Processing Record 43 of Set 13 | quatre cocos
# Processing Record 44 of Set 13 | santiago del estero
# Processing Record 45 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 13 | kattivakkam
# Processing Record 47 of Set 13 | svetlyy
# Processing Record 48 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 49 of Set 13 | benjamin constant
# Processing Record 50 of Set 13 | manali
# Processing Record 1 of Set 14 | thaba-tseka
# Processing Record 2 of Set 14 | constitucion
# Processing Record 3 of Set 14 | raudeberg
# Processing Record 4 of Set 14 | kouroussa
# Processing Record 5 of Set 14 | muravlenko
# Processing Record 6 of Set 14 | kostomuksha
# Processing Record 7 of Set 14 | farafangana
# Processing Record 8 of Set 14 | savannakhet
# Processing Record 9 of Set 14 | fort dodge
# Processing Record 10 of Set 14 | ahtopol
# Processing Record 11 of Set 14 | khormuj
# City not found. Skipping...
# Processing Record 12 of Set 14 | naze
# Processing Record 13 of Set 14 | acapulco
# Processing Record 14 of Set 14 | ugoofaaru
# Processing Record 15 of Set 14 | aljustrel
# Processing Record 16 of Set 14 | adrar
# Processing Record 17 of Set 14 | cockburn town
# Processing Record 18 of Set 14 | cochrane
# Processing Record 19 of Set 14 | sosnogorsk
# Processing Record 20 of Set 14 | ketchikan
# Processing Record 21 of Set 14 | sicuani
# Processing Record 22 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 23 of Set 14 | saint anthony
# Processing Record 24 of Set 14 | cazones
# Processing Record 25 of Set 14 | sao raimundo nonato
# Processing Record 26 of Set 14 | bequimao
# Processing Record 27 of Set 14 | santa rosa
# Processing Record 28 of Set 14 | khasan
# Processing Record 29 of Set 14 | varzea grande
# Processing Record 30 of Set 14 | mapastepec
# Processing Record 31 of Set 14 | manacapuru
# Processing Record 32 of Set 14 | bemidji
# Processing Record 33 of Set 14 | hualmay
# Processing Record 34 of Set 14 | buckeye
# Processing Record 35 of Set 14 | susanville
# Processing Record 36 of Set 14 | baglan
# Processing Record 37 of Set 14 | comodoro rivadavia
# Processing Record 38 of Set 14 | calama
# Processing Record 39 of Set 14 | fort-shevchenko
# Processing Record 40 of Set 14 | hildburghausen
# Processing Record 41 of Set 14 | meyungs
# City not found. Skipping...
# Processing Record 42 of Set 14 | mokhsogollokh
# Processing Record 43 of Set 14 | palu
# Processing Record 44 of Set 14 | finote selam
# Processing Record 45 of Set 14 | murray bridge
# Processing Record 46 of Set 14 | tornio
# Processing Record 47 of Set 14 | onguday
# Processing Record 48 of Set 14 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 14 | ulaangom
# Processing Record 50 of Set 14 | leshukonskoye
# Processing Record 1 of Set 15 | colares
# Processing Record 2 of Set 15 | sholavandan
# City not found. Skipping...
# Processing Record 3 of Set 15 | charyshskoye
# Processing Record 4 of Set 15 | kamenka
# Processing Record 5 of Set 15 | penzance
# Processing Record 6 of Set 15 | avera
# Processing Record 7 of Set 15 | maragogi
# Processing Record 8 of Set 15 | donja dubica
# Processing Record 9 of Set 15 | caravelas
# Processing Record 10 of Set 15 | bambanglipuro
# Processing Record 11 of Set 15 | santa lucia
# Processing Record 12 of Set 15 | atlantic beach
# Processing Record 13 of Set 15 | alexandria
# Processing Record 14 of Set 15 | saint-francois
# Processing Record 15 of Set 15 | ixtapa
# Processing Record 16 of Set 15 | taltal
# Processing Record 17 of Set 15 | svetlaya
# Processing Record 18 of Set 15 | los llanos de aridane
# Processing Record 19 of Set 15 | khartoum
# Processing Record 20 of Set 15 | lubao
# Processing Record 21 of Set 15 | victor harbor
# Processing Record 22 of Set 15 | kobayashi
# Processing Record 23 of Set 15 | marystown
# Processing Record 24 of Set 15 | casper
# Processing Record 25 of Set 15 | waingapu
# Processing Record 26 of Set 15 | slavyansk-na-kubani
# Processing Record 27 of Set 15 | payakumbuh
# Processing Record 28 of Set 15 | connersville
# Processing Record 29 of Set 15 | conakry
# Processing Record 30 of Set 15 | yangcun
# Processing Record 31 of Set 15 | petrivka
# Processing Record 32 of Set 15 | hereford
# Processing Record 33 of Set 15 | krotoszyn
# Processing Record 34 of Set 15 | roma
# Processing Record 35 of Set 15 | nyurba
# Processing Record 36 of Set 15 | palekh
# Processing Record 37 of Set 15 | ettaiyapuram
# Processing Record 38 of Set 15 | tarakan
# Processing Record 39 of Set 15 | sulangan
# Processing Record 40 of Set 15 | letterkenny
# Processing Record 41 of Set 15 | amroha
# Processing Record 42 of Set 15 | cocobeach
# Processing Record 43 of Set 15 | tahoua
# Processing Record 44 of Set 15 | villa maria
# Processing Record 45 of Set 15 | yar-sale
# Processing Record 46 of Set 15 | normandin
# Processing Record 47 of Set 15 | toamasina
# Processing Record 48 of Set 15 | lodwar
# Processing Record 49 of Set 15 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 15 | monrovia
# Processing Record 1 of Set 16 | asuncion ocotlan
# Processing Record 2 of Set 16 | whitehorse
# Processing Record 3 of Set 16 | markova
# Processing Record 4 of Set 16 | shimoda
# Processing Record 5 of Set 16 | ilebo
# Processing Record 6 of Set 16 | listowel
# Processing Record 7 of Set 16 | college
# Processing Record 8 of Set 16 | halden
# Processing Record 9 of Set 16 | juegang
# Processing Record 10 of Set 16 | lexington park
# Processing Record 11 of Set 16 | pozo colorado
# Processing Record 12 of Set 16 | ler
# Processing Record 13 of Set 16 | suluq
# Processing Record 14 of Set 16 | namatanai
# Processing Record 15 of Set 16 | san juan
# Processing Record 16 of Set 16 | comal
# Processing Record 17 of Set 16 | aksarka
# Processing Record 18 of Set 16 | andra
# Processing Record 19 of Set 16 | zempoala
# Processing Record 20 of Set 16 | rock springs
# Processing Record 21 of Set 16 | general pico
# Processing Record 22 of Set 16 | berestechko
# Processing Record 23 of Set 16 | ossora
# Processing Record 24 of Set 16 | yanam
# Processing Record 25 of Set 16 | sakhipur
# Processing Record 26 of Set 16 | shieli
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Pringsewu      ID  -5.3582  104.9744     74.12        93         100
# 1  Broken Hill      AU -31.9500  141.4333     80.01        28          72
# 2         Hilo      US  19.7297 -155.0900     71.11        82          20
# 3  Tuktoyaktuk      CA  69.4541 -133.0374    -34.60        67          40
# 4    Esperance      AU -33.8667  121.9000     62.02        72           0
# 5   Kaitangata      NZ -46.2817  169.8464     49.93        89          31
# 6     Baykalsk      RU  51.5058  104.1469     -6.02       100         100
# 7  Svetlogorsk      BY  52.6333   29.7333     28.80        77          52
# 8    San Pedro      PH  14.3500  121.0167     79.36        92          75
# 9       Torbay      CA  47.6666  -52.7314     45.37        69         100
#
#    Wind Speed Current Description
# 0        0.89     overcast clouds
# 1       14.70       broken clouds
# 2        6.91          few clouds
# 3        5.75    scattered clouds
# 4       12.08           clear sky
# 5        3.18    scattered clouds
# 6        0.54     overcast clouds
# 7       10.83       broken clouds
# 8        5.75       broken clouds
# 9       18.41     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
